# %% [markdown]
# # Results Algorithm 1
#
# Results were copied from the output of the Algorithm1 notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('fivethirtyeight')
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['axes.edgecolor'] = 'white'
plt.rcParams['figure.facecolor'] = 'white'

# %% [markdown]
# ## Experiment 1: Repetitions of Circuit

# %%
reps = [1, 2, 3]
results_reps = [0.7314758732081567, 0.7789473684210526, 0.668421052631579, 0.35096153846153844, 0.4708994708994709, 0.5410989010989011, 0.41781622632686466, 0.5238095238095238, 0.4825268817204302, 0.5438932372318261, 0.49567809239940386, 0.6117900790797988]

ds1_f1 = results_reps[:3]
ds2_f1 = results_reps[3:6]
ds3_f1 = results_reps[6:9]
ds4_f1 = results_reps[9:]

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in reps]

for ds, f1 in enumerate([ds1_f1, ds2_f1, ds3_f1, ds4_f1]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')
    
plt.xticks(reps)
plt.xlabel('Circuit repetitions')
plt.ylabel('Macro F1 score')
plt.title('Effect of Circuit Repetitions on Macro F1 Score', fontsize=18)
#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.ylim(0.3)
plt.show()

# %% [markdown]
# ## Experiment 2: Feature maps
#
# ZZ and pauli results equivalent

# %%
feature_maps = ['ZZ', 'Z', 'Pauli']
results_feat_maps = [0.7789473684210526, 0.7236842105263157, 0.7789473684210526, 0.4708994708994709, 0.47530864197530864, 0.4708994708994709, 0.5238095238095238, 0.4488188976377953, 0.5238095238095238, 0.49567809239940386, 0.5255212077641984, 0.49567809239940386]

ds1_f1 = results_feat_maps[:3]
ds2_f1 = results_feat_maps[3:6]
ds3_f1 = results_feat_maps[6:9]
ds4_f1 = results_feat_maps[9:]

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in reps]

for ds, f1 in enumerate([ds1_f1, ds2_f1, ds3_f1, ds4_f1]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')
    
plt.xticks(reps, labels=feature_maps)
plt.xlabel('Feature maps')
plt.ylabel('Macro F1 score')
plt.title('Effect of different Feature Maps on Macro F1 Score', fontsize=18)
#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.ylim(0.3)
plt.show()

# %% [markdown]
# ### Old Pauli experiment plot

# %%
# pauli variation experiment results
ds1_paulis = [
    ['X', 'XX', 1],
    ['Y', 'XX', 2], 
    ['Z', 'XX', 3], 
    ['X', 'XY', 4], 
    ['Y', 'XY', 5], 
    ['Z', 'XY', 6], 
    ['X', 'XZ', 7], 
    ['Y', 'XZ', 8], 
    ['Z', 'XZ', 9], 
    ['X', 'YX', 10], 
    ['Y', 'YX', 11], 
    ['Z', 'YX', 12], 
    ['X', 'YY', 13], 
    ['Y', 'YY', 14], 
    ['Z', 'YY', 15], 
    ['X', 'YZ', 16], 
    ['Y', 'YZ', 17], 
    ['Z', 'YZ', 18], 
    ['X', 'ZX', 19], 
    ['Y', 'ZX', 20]
]

ds1_f1_paulis  = [
    0.7314,
    0.7789,
    0.7314,
    0.6960,
    0.5026,
    0.7032,
    0.6817,
    0.6466,
    0.7236,
    0.7432,
    0.7032,
    0.7432,
    0.6891,
    0.4074,
    0.7236,
    0.7236,
    0.7789,
    0.6621,
    0.7236,
    0.7161
]


ds1_paulis_results = list(zip(ds1_paulis, ds1_f1_paulis))


# reorder results by first pauli
grouped_by_first_pauli = [
    [x for x in ds1_paulis_results if x[0][0] == first]
    for first in ['X', 'Y', 'Z']
]


x_ticks = range(len(ds1_f1_paulis))


first = ['X', 'Y', 'Z']

for i in range(len(grouped_by_first_pauli)):
    plt.bar(
        x_ticks[i*7:i*7+7],
        [f1[1] for f1 in grouped_by_first_pauli[i]],
        label=first[i]
    )

x_labels = [[p[0][1] for p in pauli]
            for pauli in grouped_by_first_pauli
]
# flatten
x_labels = [item for sublist in x_labels for item in sublist]

plt.xticks(x_ticks, x_labels)
plt.xlabel('Second Pauli')
plt.ylabel('Macro F1 score')
plt.title('Macro F1 Score \n for different Pauli Feature Map Variations')
plt.legend(title='First Pauli', bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.ylim(0.4)


# old feature map results (with duplicates)
#feature_maps = [1,2,3]
#ds1_f1_featmaps = [0.7789473684210526, 0.7236842105263157, 0.7789473684210526]
#ds2_f1_featmaps = [0.4708994708994709, 0.47530864197530864, 0.4708994708994709]
#ds3_f1_featmaps = [0.5238095238095238, 0.4488188976377953, 0.5238095238095238]
#ds4_f1_featmaps = [0.49567809239940386, 0.5255212077641984, 0.49567809239940386]

#plt.plot(feature_maps, ds1_f1_featmaps, label='DS1')
#plt.plot(feature_maps, ds2_f1_featmaps, label='DS2')
#plt.plot(feature_maps, ds3_f1_featmaps, label='DS3')
#plt.plot(feature_maps, ds4_f1_featmaps, label='DS4')
#
#plt.xticks(feature_maps, ['ZZ', 'Z', 'Pauli'])
#plt.xlabel('Feature maps')
#plt.ylabel('Macro F1 score')
#plt.title('F1 Score for different Feature Maps')
#plt.legend()
plt.show()

# %% [markdown]
# ## Experiment 3: Data maps

# %%
data_maps = [1, 2, 3]
results_data_maps = [0.7789473684210526, 0.7106640947919538, 0.6621404208765043, 0.4708994708994709, 0.39704433497536945, 0.45357142857142857, 0.5238095238095238, 0.45604946524064177, 0.39383593531766964, 0.49567809239940386, 0.4425806451612903, 0.5171385991058122]

ds1_data_map = results_data_maps[:3]
ds2_data_map = results_data_maps[3:6]
ds3_data_map = results_data_maps[6:9]
ds4_data_map = results_data_maps[9:]

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in reps]

for ds, f1 in enumerate([ds1_data_map, ds2_data_map, ds3_data_map, ds4_data_map]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')

plt.xticks(data_maps, ['self product', 'custom', 'superfidelity'])
plt.xlabel('Data Map')
plt.ylabel('Macro F1 score')
plt.title('Macro F1 Score for different Data Maps', fontsize=18)
plt.ylim(0.35)
#plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.show()

# %% [markdown]
# ## Experiment 4: Comparison to Classical SVMs
#
# Compare best of classical methods to best of quantum methods

# %%
kernel_list = ['rbf', 'linear', 'poly', 'sigmoid']
results_classical = [0.6749444780940843, 0.9171052631578946, 0.9171052631578946, 0.08695652173913042, 0.5330934649820098, 0.5881006864988558, 0.5881006864988558, 0.5881006864988558, 0.44148936170212766, 0.466172552142354, 0.4763827919227393, 0.4473684210526316, 0.5987654320987654, 0.537037037037037, 0.5330934649820098, 0.5330934649820098]

ds1_f1 = results_classical[:4]
ds2_f1 = results_classical[4:8]
ds3_f1 = results_classical[8:12]
ds4_f1 = results_classical[12:]

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in [1,2,3,4]]

for ds, f1 in enumerate([ds1_f1, ds2_f1, ds3_f1, ds4_f1]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')

plt.xticks([1,2,3,4], kernel_list)
plt.xlabel('Kernel')
plt.ylabel('Macro F1 score')
plt.title('Macro F1 Score for different classical Kernels', fontsize=18)
#plt.ylim(0.35)
#plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.legend()
plt.show()

# %% [markdown]
# Reverse plot with datasets as x-axis

# %%
kernels_f1 = []
for i in range(4):
    kernels_f1.append(results_classical[i::4])

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in [1,2,3,4]]

for ds, f1 in enumerate(kernels_f1):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=kernel_list[ds])

plt.xticks([1,2,3,4])
plt.xlabel('Dataset')
plt.ylabel('Macro F1 score')
plt.title('Macro F1 Score performance of different classical Kernels \n on each dataset', fontsize=18)
#plt.ylim(0.35)
plt.legend()
plt.show()

# %% [markdown]
# Find best for each dataset

# %%
for i, results in enumerate([ds1_f1, ds2_f1, ds3_f1, ds4_f1], start=1):
    best = np.argmax(results)
    print(f'Dataset {i} best kernel: {kernel_list[best]} \t({results[best]*100:.2f}%)')
# Out:
# Dataset 1 best kernel: linear 	(91.71%)
# Dataset 2 best kernel: linear 	(58.81%)
# Dataset 3 best kernel: poly 	(47.64%)
# Dataset 4 best kernel: rbf 	(59.88%)

# %% [markdown]
# ### Best classical and quantum comparison

# %% [raw]
# best quantum
# DS1: 0.7789 with defaults, i.e. reps=2 and data_map=self product
# DS2: 0.5061 with reps=3 (0.4708 with defaults)
# DS3: 0.5238 with defaults
# DS4: 0.6117 with reps=3 (0.5171 with data_map=superfidelity)

# %%
best_f1_classical = [0.9171, 0.5881, 0.4764, 0.5988]
best_f1_quantum = [0.7789, 0.5061, 0.5238, 0.6117]

datasets=[1,2,3,4]
bar_width = 0.2
coeffs = [-0.5, 0.5]
label = ['Classical', 'Quantum']

def grouped_bars(ds):
    return [dataset + bar_width*coeffs[ds] for dataset in datasets]

for ds, f1 in enumerate([best_f1_classical, best_f1_quantum]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=label[ds])
    
plt.xticks([1,2,3,4], ['D1', 'D2', 'D3', 'D4'])
plt.xlabel('Datasets')
plt.ylabel('Macro F1 score')
plt.title('Comparison of Macro F1 Score \n for Best Performing Classical and Quantum SVMs', fontsize=18)
plt.legend()
plt.ylim(0.35)
plt.show()

# %% [markdown]
# ## Experiments with no effect on F1

# %% [markdown]
# ### Experiment 5: Entanglements
#
# No effect on F1

# %%
entanglements = ['full', 'linear']
results_entanglement = [0.7789473684210526, 0.7789473684210526, 0.4708994708994709, 0.4708994708994709, 0.5238095238095238, 0.5238095238095238, 0.49567809239940386, 0.49567809239940386]

ds1_f1 = results_entanglement[:2]
ds2_f1 = results_entanglement[2:4]
ds3_f1 = results_entanglement[4:6]
ds4_f1 = results_entanglement[6:8]

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in [1, 2]]

for ds, f1 in enumerate([ds1_f1, ds2_f1, ds3_f1, ds4_f1]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')
    
plt.xticks([1,2], labels=entanglements)
plt.xlabel('Entanglements')
plt.ylabel('Macro F1 score')
plt.title('Effect of Entanglement on Macro F1 Score', fontsize=18)
plt.legend()
#plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.ylim(0.3)
plt.show()

# %% [markdown]
# ### Experiment 6: Shots
#
# 1 or 3 shots has no effect on F1

# %%
shots = [1, 3]
results_shots = [0.7789473684210526, 0.7789473684210526, 0.4708994708994709, 0.4708994708994709, 0.5238095238095238, 0.5238095238095238, 0.49567809239940386, 0.49567809239940386]

ds1_f1 = results_shots[:2]
ds2_f1 = results_shots[2:4]
ds3_f1 = results_shots[4:6]
ds4_f1 = results_shots[6:8]

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in [1, 2]]

for ds, f1 in enumerate([ds1_f1, ds2_f1, ds3_f1, ds4_f1]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')
    
plt.xticks([1,2], labels=shots)
plt.xlabel('Shots')
plt.ylabel('Macro F1 score')
plt.title('Effect of Shots on Macro F1 Score', fontsize=18)
plt.legend()
#plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.ylim(0.3)
plt.show()

# %% [markdown]
# # Results Algorithm 2

# %%
frqi_results = [0.412058794120588, 0.3881118881118881, 0.17489035087719296, 0.2664369796152742, 0.4133991972831121, 0.3899124131682271, 0.4218151995626025, 0.4351732991014121, 0.4671201814058957, 0.40785616572210276, 0.35099836069979307, 0.3842943553712459, 0.42761065828429395, 0.3767665347654042, 0.405048076923077, 0.3660866836361101]

ds1_f1 = frqi_results[:4]
ds2_f1 = frqi_results[4:8]
ds3_f1 = frqi_results[8:12]
ds4_f1 = frqi_results[12:]

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in [1,2,3,4]]

for ds, f1 in enumerate([ds1_f1, ds2_f1, ds3_f1, ds4_f1]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')
    
plt.xticks([1,2,3,4], labels=[2,4,6,8])
plt.xlabel('Layers')
plt.ylabel('Macro F1 score')
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.ylim(0.15)
plt.title('Effect of number of layers on VQOCC \n  performance using FRQI encoding', fontsize=18)
plt.show()

print(ds4_f1)
# Out:
# [0.42761065828429395, 0.3767665347654042, 0.405048076923077, 0.3660866836361101]

# %%
amplitude_results = [0.37443068514734484, 0.2268181818181818, 0.42471645459433166, 0.28823474788745473, 0.40561702127659577, 0.3098640641338446, 0.19911012235817577, 0.3098640641338446, 0.39245756419775213, 0.3126838060905037, 0.34375, 0.35919790758500436, 0.3713475569694664, 0.3287037037037037, 0.3699789992999767, 0.19422061683801056]

ds1_f1 = amplitude_results[:4]
ds2_f1 = amplitude_results[4:8]
ds3_f1 = amplitude_results[8:12]
ds4_f1 = amplitude_results[12:]

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in [1,2,3,4]]

for ds, f1 in enumerate([ds1_f1, ds2_f1, ds3_f1, ds4_f1]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')
    
plt.xticks([1,2,3,4], labels=[2,4,6,8])
plt.xlabel('Layers')
plt.ylabel('Macro F1 score')
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.ylim(0.15)
plt.title('Effect of number of layers on VQOCC \n  performance using Amplitude encoding', fontsize=18)
plt.show()

print(ds4_f1)
# Out:
# [0.3713475569694664, 0.3287037037037037, 0.3699789992999767, 0.19422061683801056]

# %% [markdown]
# # Best comparisons overall on artificial data

# %%
fig, ax = plt.subplots(2,2, figsize=(16,16), sharex=False, sharey=True)

# -- Data from Experiment 4
kernel_list = ['rbf', 'linear', 'poly', 'sigmoid']
results_classical = [0.6749444780940843, 0.9171052631578946, 0.9171052631578946, 0.08695652173913042, 0.5330934649820098, 0.5881006864988558, 0.5881006864988558, 0.5881006864988558, 0.44148936170212766, 0.466172552142354, 0.4763827919227393, 0.4473684210526316, 0.5987654320987654, 0.537037037037037, 0.5330934649820098, 0.5330934649820098]

ds1_f1 = results_classical[:4]
ds2_f1 = results_classical[4:8]
ds3_f1 = results_classical[8:12]
ds4_f1 = results_classical[12:]
# --

#best_f1_classical = [0.9171, 0.5881, 0.4764, 0.5988]
best_f1_qsvm = [0.7789, 0.5061, 0.5238, 0.6117]

# DS1: Amplitude encoding, 6 layers
# DS2: FRQI encoding, 8 layers
# DS3: FRQI encoding, 2 layers
# DS4: FRQI encoding, 2 layers
best_f1_vqocc = [0.4247, 0.4351, 0.4671, 0.4276]

# VQC: 0.4700 macro F1 on datasets 1 and 3, and 0.4767 macro F1 on datasets 2 and 4
best_f1_vqc = [0.4700, 0.4767, 0.4700, 0.4767]


datasets=[1,2,3,4]
bar_width = 0.5
coeffs = [-0.5, 0.5]
label = ['Classical', 'Quantum']

# make one subplot for each dataset
for i in range(4):
    
    current_ax = ax[i//2, i%2]
    current_ax.bar(kernel_list, results_classical[i*4:(i+1)*4], width=bar_width,
                                    label='Classical') 

    current_ax.bar(['OC-SVM', 'VQOCC', 'VQC'], [best_f1_qsvm[i], best_f1_vqocc[i], best_f1_vqc[i]], width=bar_width, label='Quantum')
    current_ax.set_title(f'Dataset {i+1}')


fig.suptitle('Comparison of Macro F1 Score \n for Classical and Best Performing Quantum settings', fontsize=18)
ax[0,1].legend()
ax[0,0].set_ylabel('Macro F1 score')
ax[1,0].set_ylabel('Macro F1 score')
plt.show()
