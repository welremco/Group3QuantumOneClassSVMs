# %% [markdown]
# # Results
#
# Available data:
#
# 4 datasets
# 3 experiments per dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Experiment 1: Repetitions of Circuit

# %% [raw]
# DS1:
#
# Experiment with number of repetitions 1,2,3
# For reps: 1
# Accuracy: 0.9095238095238095
# Precision 1: 0.9476439790575916
# Precision -1: 0.5263157894736842
# Recall 1: 0.7263157894736842
# F1 1: 0.7314758732081567
# For reps: 2
# Accuracy: 0.9238095238095239
# Precision 1: 0.9578947368421052
# Precision -1: 0.6
# Recall 1: 0.7789473684210526
# F1 1: 0.7789473684210526
# For reps: 3
# Accuracy: 0.8857142857142857
# Precision 1: 0.9368421052631579
# Precision -1: 0.4
# Recall 1: 0.668421052631579
# F1 1: 0.668421052631579
#
#
# DS2:
#
# Experiment with number of repetitions 1,2,3
# For reps: 1
# Accuracy: 0.4666666666666667
# Precision 1: 0.8333333333333334
# Precision -1: 0.047619047619047616
# Recall 1: 0.35
# F1 1: 0.35096153846153844
# For reps: 2
# Accuracy: 0.6944444444444444
# Precision 1: 0.8832116788321168
# Precision -1: 0.09302325581395349
# Recall 1: 0.478125
# F1 1: 0.4708994708994709
# For reps: 3
# Accuracy: 0.8222222222222222
# Precision 1: 0.8902439024390244
# Precision -1: 0.125
# Recall 1: 0.50625
# F1 1: 0.5061728395061729
#
#
# DS3:
#
# Experiment with number of repetitions 1,2,3
# For reps: 1
# Accuracy: 0.6047619047619047
# Precision 1: 0.8848920863309353
# Precision -1: 0.056338028169014086
# Recall 1: 0.4236842105263158
# F1 1: 0.41781622632686466
# For reps: 2
# Accuracy: 0.6952380952380952
# Precision 1: 0.9315068493150684
# Precision -1: 0.15625
# Recall 1: 0.6078947368421053
# F1 1: 0.5238095238095238
# For reps: 3
# Accuracy: 0.7904761904761904
# Precision 1: 0.9010989010989011
# Precision -1: 0.07142857142857142
# Recall 1: 0.48157894736842105
# F1 1: 0.4825268817204302
#
#
# DS4:
#
# Experiment with number of repetitions 1,2,3
# For reps: 1
# Accuracy: 0.75
# Precision 1: 0.9078014184397163
# Precision -1: 0.1794871794871795
# Recall 1: 0.575
# F1 1: 0.5438932372318261
# For reps: 2
# Accuracy: 0.7388888888888889
# Precision 1: 0.8896551724137931
# Precision -1: 0.11428571428571428
# Recall 1: 0.503125
# F1 1: 0.49567809239940386
# For reps: 3
# Accuracy: 0.85
# Precision 1: 0.9130434782608695
# Precision -1: 0.3157894736842105
# Recall 1: 0.609375
# F1 1: 0.6117900790797988

# %%
reps = [1, 2, 3]
ds1_precision_inliers = [0.9476, 0.9578, 0.9368]
ds1_precision_outliers = [0.5263, 0.6, 0.4]
ds1_recall_inliers = [0.7263, 0.7789, 0.6684]

ds1_f1_inliers = [0.7314, 0.7789, 0.6684]
ds2_f1_inliers = [0.3509, 0.4708, 0.5061]
ds3_f1_inliers = [0.4178, 0.5238, 0.4825]
ds4_f1_inliers = [0.5438, 0.4956, 0.6117]


#plt.plot(reps, ds1_precision_inliers, label='precision inliers')
#plt.plot(reps, ds1_precision_outliers, label='precision outliers')
#plt.plot(reps, ds1_recall_inliers, label='recall inliers')

#plt.plot(reps, ds1_f1_inliers, label='D1')
#plt.plot(reps, ds2_f1_inliers, label='D2')
#plt.plot(reps, ds3_f1_inliers, label='D3')
#plt.plot(reps, ds4_f1_inliers, label='D4')

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in reps]

for ds, f1 in enumerate([ds1_f1_inliers, ds2_f1_inliers, ds3_f1_inliers, ds4_f1_inliers]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')
    
plt.xticks(reps)
plt.xlabel('Circuit repetitions')
plt.ylabel('Macro F1 score')
plt.title('Effect of Circuit Repetitions on Macro F1 Score')
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.ylim(0.3)
plt.plot()
# Out:
# []

# %% [markdown]
# ## Experiment 2: Feature maps

# %% [raw]
# DS1:
#
# Experiment with different Feature maps
# For feature_map: 1
# Accuracy: 0.9238095238095239
# Precision 1: 0.9578947368421052
# Precision -1: 0.6
# Recall 1: 0.7789473684210526
# F1 1: 0.7789473684210526
# For feature_map: 2
# Accuracy: 0.9047619047619048
# Precision 1: 0.9473684210526315
# Precision -1: 0.5
# Recall 1: 0.7236842105263157
# F1 1: 0.7236842105263157
# For feature_map: 3
# Accuracy: 0.9238095238095239
# Precision 1: 0.9578947368421052
# Precision -1: 0.6
# Recall 1: 0.7789473684210526
# F1 1: 0.7789473684210526
#
#
# DS2:
#
# Experiment with different Feature maps
# For feature_map: 1
# Accuracy: 0.6944444444444444
# Precision 1: 0.8832116788321168
# Precision -1: 0.09302325581395349
# Recall 1: 0.478125
# F1 1: 0.4708994708994709
# For feature_map: 2
# Accuracy: 0.8111111111111111
# Precision 1: 0.8841463414634146
# Precision -1: 0.0625
# Recall 1: 0.478125
# F1 1: 0.47530864197530864
# For feature_map: 3
# Accuracy: 0.6944444444444444
# Precision 1: 0.8832116788321168
# Precision -1: 0.09302325581395349
# Recall 1: 0.478125
# F1 1: 0.4708994708994709
#
#
# DS3:
#
# Experiment with different Feature maps
# For feature_map: 1
# Accuracy: 0.6952380952380952
# Precision 1: 0.9315068493150684
# Precision -1: 0.15625
# Recall 1: 0.6078947368421053
# F1 1: 0.5238095238095238
# For feature_map: 2
# Accuracy: 0.8142857142857143
# Precision 1: 0.8952879581151832
# Precision -1: 0.0
# Recall 1: 0.45
# F1 1: 0.4488188976377953
# For feature_map: 3
# Accuracy: 0.6952380952380952
# Precision 1: 0.9315068493150684
# Precision -1: 0.15625
# Recall 1: 0.6078947368421053
# F1 1: 0.5238095238095238
#
#
# DS4:
#
# Experiment with different Feature maps
# For feature_map: 1
# Accuracy: 0.7388888888888889
# Precision 1: 0.8896551724137931
# Precision -1: 0.11428571428571428
# Recall 1: 0.503125
# F1 1: 0.49567809239940386
# For feature_map: 2
# Accuracy: 0.8166666666666667
# Precision 1: 0.8944099378881988
# Precision -1: 0.15789473684210525
# Recall 1: 0.525
# F1 1: 0.5255212077641984
# For feature_map: 3
# Accuracy: 0.7388888888888889
# Precision 1: 0.8896551724137931
# Precision -1: 0.11428571428571428
# Recall 1: 0.503125
# F1 1: 0.49567809239940386

# %%
# pauli variation experiment results
ds1_paulis = [
    ['X', 'XX', 1],
    ['Y', 'XX', 2], 
    ['Z', 'XX', 3], 
    ['X', 'XY', 4], 
    ['Y', 'XY', 5], 
    ['Z', 'XY', 6], 
    ['X', 'XZ', 7], 
    ['Y', 'XZ', 8], 
    ['Z', 'XZ', 9], 
    ['X', 'YX', 10], 
    ['Y', 'YX', 11], 
    ['Z', 'YX', 12], 
    ['X', 'YY', 13], 
    ['Y', 'YY', 14], 
    ['Z', 'YY', 15], 
    ['X', 'YZ', 16], 
    ['Y', 'YZ', 17], 
    ['Z', 'YZ', 18], 
    ['X', 'ZX', 19], 
    ['Y', 'ZX', 20]
]

ds1_f1_paulis  = [
    0.7314,
    0.7789,
    0.7314,
    0.6960,
    0.5026,
    0.7032,
    0.6817,
    0.6466,
    0.7236,
    0.7432,
    0.7032,
    0.7432,
    0.6891,
    0.4074,
    0.7236,
    0.7236,
    0.7789,
    0.6621,
    0.7236,
    0.7161
]


ds1_paulis_results = list(zip(ds1_paulis, ds1_f1_paulis))


# reorder results by first pauli
grouped_by_first_pauli = [
    [x for x in ds1_paulis_results if x[0][0] == first]
    for first in ['X', 'Y', 'Z']
]


x_ticks = range(len(ds1_f1_paulis))


first = ['X', 'Y', 'Z']

for i in range(len(grouped_by_first_pauli)):
    plt.bar(
        x_ticks[i*7:i*7+7],
        [f1[1] for f1 in grouped_by_first_pauli[i]],
        label=first[i]
    )

x_labels = [[p[0][1] for p in pauli]
            for pauli in grouped_by_first_pauli
]
# flatten
x_labels = [item for sublist in x_labels for item in sublist]

plt.xticks(x_ticks, x_labels)
plt.xlabel('Second Pauli')
plt.ylabel('Macro F1 score')
plt.title('Macro F1 Score \n for different Pauli Feature Map Variations')
plt.legend(title='First Pauli', bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.ylim(0.4)


# old feature map results (with duplicates)
#feature_maps = [1,2,3]
#ds1_f1_featmaps = [0.7789473684210526, 0.7236842105263157, 0.7789473684210526]
#ds2_f1_featmaps = [0.4708994708994709, 0.47530864197530864, 0.4708994708994709]
#ds3_f1_featmaps = [0.5238095238095238, 0.4488188976377953, 0.5238095238095238]
#ds4_f1_featmaps = [0.49567809239940386, 0.5255212077641984, 0.49567809239940386]

#plt.plot(feature_maps, ds1_f1_featmaps, label='DS1')
#plt.plot(feature_maps, ds2_f1_featmaps, label='DS2')
#plt.plot(feature_maps, ds3_f1_featmaps, label='DS3')
#plt.plot(feature_maps, ds4_f1_featmaps, label='DS4')
#
#plt.xticks(feature_maps, ['ZZ', 'Z', 'Pauli'])
#plt.xlabel('Feature maps')
#plt.ylabel('Macro F1 score')
#plt.title('F1 Score for different Feature Maps')
#plt.legend()
plt.show()

# %% [markdown]
# ## Experiment 3: Data maps

# %% [raw]
# DS1:
#
# Experiment with different data_maps
# For data_map: 1
# Accuracy: 0.9238095238095239
# Precision 1: 0.9578947368421052
# Precision -1: 0.6
# Recall 1: 0.7789473684210526
# F1 1: 0.7789473684210526
# For data_map: 2
# Accuracy: 0.9
# Precision 1: 0.9424083769633508
# Precision -1: 0.47368421052631576
# Recall 1: 0.6986842105263158
# F1 1: 0.7032101756511205
# For data_map: 3
# Accuracy: 0.8809523809523809
# Precision 1: 0.9365079365079365
# Precision -1: 0.38095238095238093
# Recall 1: 0.6657894736842105
# F1 1: 0.6621404208765043
#
#
# DS2:
#
# Experiment with different data_maps
# For data_map: 1
# Accuracy: 0.6944444444444444
# Precision 1: 0.8832116788321168
# Precision -1: 0.09302325581395349
# Recall 1: 0.478125
# F1 1: 0.4708994708994709
# For data_map: 2
# Accuracy: 0.6222222222222222
# Precision 1: 0.8538461538461538
# Precision -1: 0.02
# Recall 1: 0.371875
# F1 1: 0.39704433497536945
# For data_map: 3
# Accuracy: 0.6222222222222222
# Precision 1: 0.8833333333333333
# Precision -1: 0.1
# Recall 1: 0.48124999999999996
# F1 1: 0.45357142857142857
#
#
# DS3:
#
# Experiment with different data_maps
# For data_map: 1
# Accuracy: 0.6952380952380952
# Precision 1: 0.9315068493150684
# Precision -1: 0.15625
# Recall 1: 0.6078947368421053
# F1 1: 0.5238095238095238
# For data_map: 2
# Accuracy: 0.7047619047619048
# Precision 1: 0.8950617283950617
# Precision -1: 0.0625
# Recall 1: 0.4565789473684211
# F1 1: 0.45604946524064177
# For data_map: 3
# Accuracy: 0.5571428571428572
# Precision 1: 0.875968992248062
# Precision -1: 0.04938271604938271
# Recall 1: 0.3973684210526316
# F1 1: 0.39383593531766964
#
#
# DS4:
#
# Experiment with different data_maps
# For data_map: 1
# Accuracy: 0.7388888888888889
# Precision 1: 0.8896551724137931
# Precision -1: 0.11428571428571428
# Recall 1: 0.503125
# F1 1: 0.49567809239940386
# For data_map: 2
# Accuracy: 0.7333333333333333
# Precision 1: 0.8733333333333333
# Precision -1: 0.03333333333333333
# Recall 1: 0.434375
# F1 1: 0.4425806451612903
# For data_map: 3
# Accuracy: 0.75
# Precision 1: 0.896551724137931
# Precision -1: 0.14285714285714285
# Recall 1: 0.53125
# F1 1: 0.5171385991058122

# %%
data_maps = [1, 2, 3]

ds1_data_map = [0.7789, 0.7032, 0.6621]
ds2_data_map = [0.4708, 0.3970, 0.4535]
ds3_data_map = [0.5238, 0.4560, 0.3938]
ds4_data_map = [0.4956, 0.4425, 0.5171]

#plt.plot(data_maps, ds1_data_map, label='DS1')
#plt.plot(data_maps, ds2_data_map, label='DS2')
#plt.plot(data_maps, ds3_data_map, label='DS3')
#plt.plot(data_maps, ds4_data_map, label='DS4')

bar_width = 0.2

coeffs = [-1.5, -0.5, 0.5, 1.5]

def grouped_bars(ds):
    return [rep + bar_width*coeffs[ds] for rep in reps]

for ds, f1 in enumerate([ds1_data_map, ds2_data_map, ds3_data_map, ds4_data_map]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=f'Dataset {ds+1}')

plt.xticks(data_maps, ['self product', 'custom', 'superfidelity'])
plt.xlabel('Data Map')
plt.ylabel('Macro F1 score')
plt.title('Macro F1 Score for different Data Maps')
plt.ylim(0.35)
plt.legend()
plt.show()

# %% [markdown]
# ## Experiment 4: Comparison to Classical SVMs
#
# Compare best of classical methods to best of quantum methods

# %% [raw]
# best ones for classical
# DS1: Linear SVM,Accuracy: 0.9714,Precision 1: 0.9842, Precision -1: 0.85
# DS2: Poly SVM, 0.8444, precision 1: 0.907407,precision -1:  0.277777
# DS3: Sigmoid SVM, Accuracy: 0.8095238095238095 Precision 1: 0.8947368421052632Precision -1: 0.0
# DS4: RBF SVM, Accuracy: 0.8555555555555555 Precision 1: 0.9085365853658537 Precision -1: 0.3125
#
#
# best quantum
# DS1: 0.7789 with defaults, i.e. reps=2 and data_map=self product
# DS2: 0.5061 with reps=3 (0.4708 with defaults)
# DS3: 0.5238 with defaults
# DS4: 0.6117 with reps=3 (0.5171 with data_map=superfidelity)

# %% [raw]
# Classical:
#
# DS1 best:
#
# linear:
# Accuracy: 0.9714285714285714
# Precision 1: 0.9842105263157894
# Precision -1: 0.85
# Recall 1: 0.9171052631578946
# F1 1: 0.9171052631578946
#
#
# DS2 best:
#
# poly:
# Accuracy: 0.8444444444444444
# Precision 1: 0.9074074074074074
# Precision -1: 0.2777777777777778
# Recall 1: 0.584375
# F1 1: 0.5881006864988558
#
#
# DS3 best:
#
# sigmoid:
# Accuracy: 0.8095238095238095
# Precision 1: 0.8947368421052632
# Precision -1: 0.0
# Recall 1: 0.4473684210526316
# F1 1: 0.4473684210526316
#
#
# DS4 best:
#
# rbf:
# Accuracy: 0.8555555555555555
# Precision 1: 0.9085365853658537
# Precision -1: 0.3125
# Recall 1: 0.590625
# F1 1: 0.5987654320987654

# %%
best_f1_classical = [0.9171, 0.5881, 0.4473, 0.5987]
best_f1_quantum = [0.7789, 0.5061, 0.5238, 0.6117]

datasets=[1,2,3,4]
bar_width = 0.2
coeffs = [-0.5, 0.5]
label = ['Classical', 'Quantum']

def grouped_bars(ds):
    return [dataset + bar_width*coeffs[ds] for dataset in datasets]

for ds, f1 in enumerate([best_f1_classical, best_f1_quantum]):
    plt.bar(grouped_bars(ds), f1, width=bar_width, label=label[ds])
    
plt.xticks([1,2,3,4], ['D1', 'D2', 'D3', 'D4'])
plt.xlabel('Datasets')
plt.ylabel('Macro F1 score')
plt.title('Comparison of Macro F1 Score \n for Best Performing Classical and Quantum SVMs')
plt.legend()
plt.ylim(0.35)
plt.plot()
# Out:
# []
